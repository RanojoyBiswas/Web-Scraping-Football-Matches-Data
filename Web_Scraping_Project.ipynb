# %% [markdown]
# <a href="https://colab.research.google.com/github/RanojoyBiswas/Web-Scraping-Football-Matches-Data/blob/main/Web_Scraping_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
import pandas as pd
import numpy
from bs4 import BeautifulSoup
import time

# %%
standings_url = 'https://fbref.com/en/comps/9/2021-2022/2021-2022-Premier-League-Stats'

# %%
data = requests.get(standings_url)

# %%
data.text

# %%
soup = BeautifulSoup(data.text)

# soup
# soup.select('table.stats_table')

# %%
standings_table = soup.select('table.stats_table')[0]

# standings_table

# %%
links = standings_table.find_all('a')

h_links = [l.get('href') for l in links]

final_links = [l for l in h_links if '/squads/' in l]

# %%
print(len(final_links))

final_links
# Out:
# 20
# ['/en/squads/b8fd03ef/2021-2022/Manchester-City-Stats',
#  '/en/squads/822bd0ba/2021-2022/Liverpool-Stats',
#  '/en/squads/cff3d9bb/2021-2022/Chelsea-Stats',
#  '/en/squads/361ca564/2021-2022/Tottenham-Hotspur-Stats',
#  '/en/squads/18bb7c10/2021-2022/Arsenal-Stats',
#  '/en/squads/19538871/2021-2022/Manchester-United-Stats',
#  '/en/squads/7c21e445/2021-2022/West-Ham-United-Stats',
#  '/en/squads/a2d435b3/2021-2022/Leicester-City-Stats',
#  '/en/squads/d07537b9/2021-2022/Brighton-and-Hove-Albion-Stats',
#  '/en/squads/8cec06e1/2021-2022/Wolverhampton-Wanderers-Stats',
#  '/en/squads/b2b47a98/2021-2022/Newcastle-United-Stats',
#  '/en/squads/47c64c55/2021-2022/Crystal-Palace-Stats',
#  '/en/squads/cd051869/2021-2022/Brentford-Stats',
#  '/en/squads/8602292d/2021-2022/Aston-Villa-Stats',
#  '/en/squads/33c895d4/2021-2022/Southampton-Stats',
#  '/en/squads/d3fd31cc/2021-2022/Everton-Stats',
#  '/en/squads/5bfb9659/2021-2022/Leeds-United-Stats',
# ...

# %%
team_urls = [f'http://fbref.com{l}' for l in final_links]

(team_urls)
# Out:
# ['http://fbref.com/en/squads/b8fd03ef/2021-2022/Manchester-City-Stats',
#  'http://fbref.com/en/squads/822bd0ba/2021-2022/Liverpool-Stats',
#  'http://fbref.com/en/squads/cff3d9bb/2021-2022/Chelsea-Stats',
#  'http://fbref.com/en/squads/361ca564/2021-2022/Tottenham-Hotspur-Stats',
#  'http://fbref.com/en/squads/18bb7c10/2021-2022/Arsenal-Stats',
#  'http://fbref.com/en/squads/19538871/2021-2022/Manchester-United-Stats',
#  'http://fbref.com/en/squads/7c21e445/2021-2022/West-Ham-United-Stats',
#  'http://fbref.com/en/squads/a2d435b3/2021-2022/Leicester-City-Stats',
#  'http://fbref.com/en/squads/d07537b9/2021-2022/Brighton-and-Hove-Albion-Stats',
#  'http://fbref.com/en/squads/8cec06e1/2021-2022/Wolverhampton-Wanderers-Stats',
#  'http://fbref.com/en/squads/b2b47a98/2021-2022/Newcastle-United-Stats',
#  'http://fbref.com/en/squads/47c64c55/2021-2022/Crystal-Palace-Stats',
#  'http://fbref.com/en/squads/cd051869/2021-2022/Brentford-Stats',
# ...

# %%
# manchester city link
team_url = team_urls[0]

team_url
# Out:
# 'http://fbref.com/en/squads/b8fd03ef/2021-2022/Manchester-City-Stats'

# %%
data = requests.get(team_url)

# data.text

# %%
# matches data
matches = pd.read_html(data.text, match = 'Scores & Fixtures')

pd.set_option('display.max_columns', None)
matches = matches[0]

# matches data
matches.head()
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2021-08-07  17:15  Community Shield  FA Community Shield  Sat  Neutral
# 1  2021-08-15  16:30    Premier League          Matchweek 1  Sun     Away
# 2  2021-08-21  15:00    Premier League          Matchweek 2  Sat     Home
# 3  2021-08-28  12:30    Premier League          Matchweek 3  Sat     Home
# 4  2021-09-11  15:00    Premier League          Matchweek 4  Sat     Away
#
#   Result GF GA        Opponent   xG  xGA  Poss  Attendance         Captain  \
# 0      L  0  1  Leicester City  NaN  NaN    57         NaN     Fernandinho
# 1      L  0  1       Tottenham  1.8  1.0    65     58262.0     Fernandinho
# 2      W  5  0    Norwich City  2.6  0.1    67     51437.0  İlkay Gündoğan
# 3      W  5  0         Arsenal  4.4  0.2    80     52276.0  İlkay Gündoğan
# 4      W  1  0  Leicester City  2.8  0.6    61     32087.0  İlkay Gündoğan
#
#   Formation          Referee  Match Report Notes
# ...

# %% [markdown]
# ### shooting data

# %%
soup = BeautifulSoup(data.text)

# %%
links = soup.find_all('a')

h_links = [l.get('href') for l in links]

final_links = [l for l in h_links if l and 'all_comps/shooting/' in l]

# %%
print(len(final_links))

final_links
# Out:
# 4
# ['/en/squads/b8fd03ef/2021-2022/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2021-2022/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2021-2022/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2021-2022/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions']

# %%
data = requests.get(f'https://fbref.com{final_links[0]}')

shooting_stats = pd.read_html(data.text, match = 'Shooting')[0]

# %%
shooting_stats.head()
# Out:
#   For Manchester City                                                     \
#                  Date   Time              Comp                Round  Day
# 0          2021-08-07  17:15  Community Shield  FA Community Shield  Sat
# 1          2021-08-15  16:30    Premier League          Matchweek 1  Sun
# 2          2021-08-21  15:00    Premier League          Matchweek 2  Sat
# 3          2021-08-28  12:30    Premier League          Matchweek 3  Sat
# 4          2021-09-11  15:00    Premier League          Matchweek 4  Sat
#
#                                         Standard                            \
#      Venue Result GF GA        Opponent      Gls  Sh SoT  SoT%  G/Sh G/SoT
# 0  Neutral      L  0  1  Leicester City        0  12   3  25.0  0.00  0.00
# 1     Away      L  0  1       Tottenham        0  18   4  22.2  0.00  0.00
# 2     Home      W  5  0    Norwich City        4  16   4  25.0  0.25  1.00
# 3     Home      W  5  0         Arsenal        5  25  10  40.0  0.20  0.50
# ...

# %%
# dropping the multilevel index
shooting_stats.columns = shooting_stats.columns.droplevel()


# shooting data for manchester city
shooting_stats.head()
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2021-08-07  17:15  Community Shield  FA Community Shield  Sat  Neutral
# 1  2021-08-15  16:30    Premier League          Matchweek 1  Sun     Away
# 2  2021-08-21  15:00    Premier League          Matchweek 2  Sat     Home
# 3  2021-08-28  12:30    Premier League          Matchweek 3  Sat     Home
# 4  2021-09-11  15:00    Premier League          Matchweek 4  Sat     Away
#
#   Result GF GA        Opponent  Gls  Sh  SoT  SoT%  G/Sh  G/SoT  Dist   FK  \
# 0      L  0  1  Leicester City    0  12    3  25.0  0.00   0.00   NaN  NaN
# 1      L  0  1       Tottenham    0  18    4  22.2  0.00   0.00  17.3  1.0
# 2      W  5  0    Norwich City    4  16    4  25.0  0.25   1.00  18.5  1.0
# 3      W  5  0         Arsenal    5  25   10  40.0  0.20   0.50  14.8  0.0
# 4      W  1  0  Leicester City    1  25    8  32.0  0.04   0.13  14.3  0.0
#
#    PK  PKatt   xG  npxG  npxG/Sh  G-xG  np:G-xG  Match Report
# ...

# %% [markdown]
# ### Merging two dataframes

# %%
mc_df = matches.merge(shooting_stats[['Date', 'Sh', 'SoT', 'Dist', 'FK', 'PK', "PKatt"]], on = 'Date')

# data of manchester city
mc_df.head()
# Out:
#          Date   Time              Comp                Round  Day    Venue  \
# 0  2021-08-07  17:15  Community Shield  FA Community Shield  Sat  Neutral
# 1  2021-08-15  16:30    Premier League          Matchweek 1  Sun     Away
# 2  2021-08-21  15:00    Premier League          Matchweek 2  Sat     Home
# 3  2021-08-28  12:30    Premier League          Matchweek 3  Sat     Home
# 4  2021-09-11  15:00    Premier League          Matchweek 4  Sat     Away
#
#   Result GF GA        Opponent   xG  xGA  Poss  Attendance         Captain  \
# 0      L  0  1  Leicester City  NaN  NaN    57         NaN     Fernandinho
# 1      L  0  1       Tottenham  1.8  1.0    65     58262.0     Fernandinho
# 2      W  5  0    Norwich City  2.6  0.1    67     51437.0  İlkay Gündoğan
# 3      W  5  0         Arsenal  4.4  0.2    80     52276.0  İlkay Gündoğan
# 4      W  1  0  Leicester City  2.8  0.6    61     32087.0  İlkay Gündoğan
#
# ...

# %% [markdown]
# ### Getting the data for all different teams --->

# %%
years = list(range(2022, 2017, -1))
years
# Out:
# [2022, 2021, 2020, 2019, 2018]

# %%
all_matches = []
standing_url = 'https://fbref.com/en/comps/9/2021-2022/2021-2022-Premier-League-Stats'

for year in years:
  data = requests.get(standing_url)
  soup = BeautifulSoup(data.text)
  standings_table = soup.select('table.stats_table')[0]

  h_links = [l.get('href') for l in standings_table.find_all('a')]
  final_links = [l for l in h_links if '/squads/' in l]
  team_urls = [f'http://fbref.com{l}' for l in final_links]

  previous_season = soup.select('a.prev')[0].get('href')
  standings_url = f'http://fbref.com{previous_season}'

  for team_url in team_urls:
    # getting team_names
    team_name = team_url.split('/')[-1].replace('-Stats', '').replace('-', ' ')
    data = requests.get(team_url)
    matches = pd.read_html(data.text, match = "Scores & Fixtures")[0]  # matches data
    soup = BeautifulSoup(data.text)
    # links of shooting data
    links = soup.find_all('a')
    s_links = [l.get('href') for l in links]
    final_s_links = [l for l in s_links if l and 'all_comps/shooting/' in l]
    data = requests.get(f'https://fbref.com{final_s_links[0]}')
    shooting_stats = pd.read_html(data.text, match = 'Shooting')[0]
    shooting_stats.columns = shooting_stats.columns.droplevel()

    # merging the matches data and shooting data
    try:
      team_data = matches.merge(shooting_stats[['Date', 'Sh', 'SoT', 'Dist', 'FK', 'PK', "PKatt"]], on = 'Date')
    except ValueError:   # when shooting stats is not available
      continue

    # only considering the premier league data
    team_data = team_data[team_data['Comp'] == 'Premier League']

    team_data['Season'] = year  # adding the year column
    team_data['Team'] = team_name
    all_matches.append(team_data)
    time.sleep(20)
# Out:
# <ipython-input-25-e4e4d0e0ab64>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_data['Season'] = year  # adding the year column
# <ipython-input-25-e4e4d0e0ab64>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_data['Team'] = team_name

# %%
match_df = pd.concat(all_matches)

# %%
match_df
# Out:
#           Date   Time            Comp         Round  Day Venue Result GF GA  \
# 1   2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0  1
# 2   2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5  0
# 3   2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5  0
# 4   2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1  0
# 6   2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0  0
# ..         ...    ...             ...           ...  ...   ...    ... .. ..
# 38  2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L  0  2
# 39  2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L  0  4
# 40  2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L  0  3
# 41  2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D  1  1
# 42  2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L  0  5
#
# ...

# %% [markdown]
# ### Making it into a csv file

# %%
match_df.to_csv('match_data.csv')

# %%
from google.colab import files
files.download('match_data.csv')

# %%
df = pd.read_csv('/content/match_data.csv')

df.head()
# Out:
#    Unnamed: 0        Date   Time            Comp        Round  Day Venue  \
# 0           1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away
# 1           2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home
# 2           3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home
# 3           4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away
# 4           6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home
#
#   Result  GF  GA        Opponent   xG  xGA  Poss  Attendance         Captain  \
# 0      L   0   1       Tottenham  1.8  1.0  65.0     58262.0     Fernandinho
# 1      W   5   0    Norwich City  2.6  0.1  67.0     51437.0  İlkay Gündoğan
# 2      W   5   0         Arsenal  4.4  0.2  80.0     52276.0  İlkay Gündoğan
# 3      W   1   0  Leicester City  2.8  0.6  61.0     32087.0  İlkay Gündoğan
# 4      D   0   0     Southampton  1.0  0.4  64.0     52698.0     Fernandinho
#
# ...
